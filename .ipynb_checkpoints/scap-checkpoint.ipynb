# %%
startlink = ['https://zh.wikisource.org/zh-hant/Wikisource:%E5%85%B8%E7%B1%8D',
             'https://zh.wikisource.org/zh-hant/Wikisource:%E5%8F%B2%E6%9B%B8']

# %%
from bs4 import BeautifulSoup
import urllib.request
import re


pattern = re.compile("^/wiki/+\%")
if pattern.match('/wiki/Author:%E7%8F%AD%E5%9B%BA'):
    print('yes')


for x in startlink:
    r = urllib.request.urlopen(x)
    soup = BeautifulSoup(r)
    li = soup.find_all('ul')

    li = soup.find_all('a',href=True) 
    txtlink = []


    for x in li:
        if pattern.match(x['href']):
            txtlink.append(x['href'])
        
print(txtlink)
# Out:
# C:\Users\Coconutisgood\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Coconutisgood\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ...

# %%
import codecs
import sys
import os
from urllib.parse import unquote
base = 'https://zh.wikisource.org/zh-hant'

txtlink2 = []
lik = 0
while 1:
    for x in txtlink:
        webpath = base + x[5:]
        r = urllib.request.urlopen(webpath) 
        soup = BeautifulSoup(r)
        li = soup.find('div' , attrs={"class": "mw-parser-output"})
        if len(li.find_all('ul')) > 2:
            lik = 1
        if lik:
            li2 = li.find_all('ul')
            li2 = soup.find_all('a',href=True) 
            for x in li2:
                if pattern.match(x['href']) and x['href'] not in used:
                    txtlink2.append(x['href'])
            lik = 0
                    
    
        else:
            name = x[6:].split('/')
            name = [unquote(i) for i in name]
            part = name[len(name)-1]
            print(part)
            p = 'I:/python/classical_chinese/labeled data'
            p = p + '/' + name[0]
            print(name[0])
            print(p)
            directory = p
            
            if not os.path.exists(directory):
                os.makedirs(directory)
        
            li = li.find_all('p')
            print( 1, unquote(part))
            
            filename = '%s.txt' % part
            with codecs.open(directory + '/'+filename, "w", "utf-8") as f:
                for item in li:
                    f.write("%s" % item.text)
    f
    if not txtlink2:
        break
    else:
        txtlink = txtlink2
        txtlink2 = []
# Out:
# C:\Users\Coconutisgood\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Coconutisgood\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 史部
# 四庫全書
# I:/python/classical_chinese/labeled data/四庫全書
# 1 史部
# 史記
# 史記
# I:/python/classical_chinese/labeled data/史記
# 1 史記
# 漢書
# 漢書
# I:/python/classical_chinese/labeled data/漢書
# 1 漢書
# 後漢書
# 後漢書
# I:/python/classical_chinese/labeled data/後漢書
# 1 後漢書
# 三國志
# 三國志
# I:/python/classical_chinese/labeled data/三國志
# 1 三國志
# 晉書
# 晉書
# ...
